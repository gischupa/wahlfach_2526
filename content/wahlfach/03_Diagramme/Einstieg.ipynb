# %% [markdown]
# # Diagramme in Python
#
# Das hat diesmal nichts mit Spielen zu tun, kann euch aber im Schulalltag (und später im Beruf) helfen.
# Diagramme und Graphen sind Grundbausteine der Naturwissenschaften und Mathematik.
# Es gibt viele Programme, um sie zu zeichnen. In der Schule sind das meistens GeoGebra und Tabellenkalkulationen.
# Beide Programme sind super, aber nur bei kleinen Datenmengen. Heute leben wir im Zeitalter von *BigData*
# und da sind diese Programme nur bedingt brauchbar!
#
# Kombinieren wir einfach Python und Diagramme!

# %% [markdown]
# ## Module
# Für Diagramme und Graphen brauchen wir eigentlich immer folgende 3 Module.
# Du kannst dir das als Baustein merken, den du einfach in jedes Projekt kopierst:
#
# ```python
# import matplotlib.pyplot as plt
# import pandas as pd
# import numpy as np
# ```
#
# Die Schreibweise mit *as ...* erlaubt uns später eine abkürzende Schreibweise.
# Für das Zeichnen ist `pyplot` zuständig, die Verwaltung großer Datenmengen teilen sich `numpy` und `pandas`.
#
# Um es gleich vorauszuschicken: Das sind Profi-Tools und damit können sie auch gar nicht einfach zu bedienen sein.
# WIR beschränken uns auf einfach Beispiele. Der große Vorteil dieser Methode ... Jede KI liefert dir problemlos
# Python-Code (also auch für Diagramme)!

# %%
### Mache hier einmalig diese Imports ...
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %% [markdown]
# ## Ein ganz einfacher Plot
# Bitte keine zu hohen erwartungen - es geht um das Prinzip! Schöner machen wir das nachher!
# Um einen Graphen zu zeichnen, brauchen wir x- und y-Werte. Hier geben wir sie per Hand an,
# später berechnen wir sie. Das geht übrigens in Physik auch für Messwerte!
#
# ```python
# x_werte = [0, 1, 2, 3, 4]
# y_werte = [ .... schreib die Quadrate in die Liste .... ]  # (Für unsere Copy & Paster :)   )
#
# plt.plot(x_werte, y_werte)
# ```
#
# Je nach System kann auch noch ein abschließendes `plt.show()` nötig sein!

# %%
# DEIN CODE

# %% [markdown]
# Klar - das sieht eckig aus, waren aber auch nur 5 Werte - was erwartest du!
# Löse dieses Problem, indem du viele Werte verwendest. Dafür brauchst du wieder einmal
# Schleifen!
#
# **Problem**
# Mit `for x in range(5)` bekommst du auch nicht mehr Werte und auch keine kleineren Abstände,
# wie sie für eine schönere Kurve nötig wären. Eine direkt Schleife über die x-Werte ist also nicht
# sinnvoll!
#
# **Lösung**
# ```python
# for nummer in range(100):   # Nummer soll für "1. x-Wert, 2. x-Wert, ..." stehen
#     ...
# ```
#
# Die Idee ist es nun, ein kleines `x` zu wählen und bei jedem Durchlauf ein weiteres solches `x` zu addieren.
# Da kennst das im Prinzip schon als $\Delta x$, beim Programmieren wird das gerne als `dx` geschrieben.
#
# ```python
# dx = # kleinen Werte setzen0.01
# x =  # Anfangswert setzen
# x_werte = # leere Liste
# y_werte = # leere Liste
# for nummer in range(100):
#     # x an x_werte anhängen
#     # x**2 an y_werte anhängen
#     x # um dx größer machen
#
# plt.plot(x_werte, y_werte)
# ```

# %%
### DEIN CODE

# %% [markdown]
# Du findest das *ziemlich lang*? Ja - das haben sich andere Menschen auch gedacht und deswegen `numpy`
# erfunden. Dieses Code-Beispiel soll dir nur zeigen, wohin die Reise gehen kann - bei deinem akutellen
# Wissensstand würden aber normales Python und numpy durcheinander kommen und dich verwirren ...
#
# ```python
# x_werte = np.linspace(0,5,100)  # zerlegt den Bereich von 0 bis 5 in 100 Teile
# y_werte = x_werte**2            # quadriert die ganze Liste auf einen "haps"
# plt.plot(x_werte, y_werte)      # kennst du schon ...
# ```

# %%
# AUSPROBIEREN
